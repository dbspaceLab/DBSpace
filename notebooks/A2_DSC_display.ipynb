# %% [markdown]
# # Aim 2: Alternative measures of Depression-Behavior
# ## The Depression State Consensus
#
# Here we'll generate the DSC from a set of clinical metrics
#
# ## Setup

# %%
import dbspace as dbo
import dbspace.readout.ClinVect as ClinVect

aggregate_measures = ClinVect.CFrame()
aggregate_measures.dsc_gen()
# Out:
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# ...

# %%
ClinVect.plot_c_vs_c()
# Out:
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# B03
# B04
# C01
# C02
# C03
# C04
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# C23
# C24
# A04
# A03
# A02
# A01
# B01
# B02
# ...
